# %%
import pandas as pd

# Load the datasets
train_path = '/content/train.csv'
test_path = '/content/test.csv'
gender_submission_path = '/content/gender_submission.csv'

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
gender_submission_df = pd.read_csv(gender_submission_path)

# Display basic information about the datasets
train_info = train_df.info()
test_info = test_df.info()
gender_submission_info = gender_submission_df.info()

# Display the first few rows of each dataset to understand the structure
train_head = train_df.head()
test_head = test_df.head()
gender_submission_head = gender_submission_df.head()

(train_info, test_info, gender_submission_info, train_head, test_head, gender_submission_head)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizing missing data in the train and test datasets
plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
sns.heatmap(train_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in Train Set')

plt.subplot(1, 2, 2)
sns.heatmap(test_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in Test Set')

plt.tight_layout()
plt.show()

# Visualizing the distribution of key features in the train dataset
def plot_distribution(feature, data, hue=None):
    plt.figure(figsize=(8,4))
    sns.histplot(data=data, x=feature, hue=hue, multiple='stack', kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# Visualizing missing data in the train and test datasets
plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
sns.heatmap(train_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in Train Set')

plt.subplot(1, 2, 2)
sns.heatmap(test_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in Test Set')

plt.tight_layout()
plt.show()

# Visualizing the distribution of key features in the train dataset
def plot_distribution(feature, data, hue=None):
    plt.figure(figsize=(8,4))
    sns.histplot(data=data, x=feature, hue=hue, multiple='stack', kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
# Plotting distributions
plot_distribution('Age', train_df, hue='Survived')

# %%
plot_distribution('Fare', train_df, hue='Survived')

# %%
plot_distribution('Pclass', train_df, hue='Survived')

# %%
plot_distribution('Sex', train_df, hue='Survived')

# %%
# Handling missing values

# Fill missing 'Age' values with the median age of each passenger class and sex
train_df['Age'] = train_df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))
test_df['Age'] = test_df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))

# Fill missing 'Embarked' values with the mode (most frequent)
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)

# Fill missing 'Fare' value in test set with the median fare
test_df['Fare'].fillna(test_df['Fare'].median(), inplace=True)

# Dropping 'Cabin' column since it has too many missing values
# Check if 'Cabin' column exists before dropping
if 'Cabin' in train_df.columns:
    train_df.drop(columns=['Cabin'], inplace=True)
if 'Cabin' in test_df.columns:
    test_df.drop(columns=['Cabin'], inplace=True)


# Check if missing values are handled
missing_data_train = train_df.isnull().sum()
missing_data_test = test_df.isnull().sum()

# Correlation heatmap to explore relationships between variables
plt.figure(figsize=(10,6))
# Select only numerical features for correlation calculation
numerical_features = train_df.select_dtypes(include=['number'])
corr_matrix = numerical_features.corr()  # Calculate correlation for numerical features only
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Train Dataset)')
plt.show()

missing_data_train, missing_data_test
# Out:
# <ipython-input-23-06dc0dd3bdc1>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
# <ipython-input-23-06dc0dd3bdc1>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
